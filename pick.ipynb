# %%
from sinar import SINAR
import pickle

# %%
model = SINAR(rf"models\best.pt", 
              "models/anbev-cnn-fix.keras", device="cpu")
# model.yolo_model.names
# Out:
# [INFO @ _sinar] - [MainProcess / MainThread] - yolo model loaded [models\best.pt]
# [INFO @ motas] - [MainProcess / MainThread] - Loading Tensorflow model models/anbev-cnn-fix.keras
# [INFO @ motas] - [MainProcess / MainThread] - Motion Analysis model loaded with type <Sequential>

# %%
model.yolo_model.model
# Out:
# DetectionModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (2): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
# ...

# %%
model.yolo_model.predictor = model.yolo_model._smart_load("predictor")()
model.yolo_model.predictor.setup_model(model=model.yolo_model.model)
# Out:
# Ultralytics YOLOv8.2.22  Python-3.11.6 torch-2.1.0+cpu CPU (12th Gen Intel Core(TM) i5-1235U)
# Loading G:\My Drive\yolov8\train\yolov9m-all-data-fix\weights\best_openvino_model for OpenVINO inference...
# Using OpenVINO CUMULATIVE_THROUGHPUT mode for batch=16 inference...

# %%
model.yolo_model.predictor = None

# %%
with open("models/sinar_yolo_cnn2.pkl", "wb") as f:
    pickle.dump(model, f)

# %%
loaded = pickle.load(open("models/sinar_yolo9m-ov_cnn.pkl", "rb"))
loaded.yolo_model.predictor

# %%
loaded.yolo_model.predictor is None
# Out:
# True

# %%
import torch

t_model = torch.load(rf"G:\My Drive\yolov8\train\yolov9m-all-data-fix\weights\best.pt", map_location="cpu")

# %%
type(t_model["model"])
# Out:
# ultralytics.nn.tasks.DetectionModel

# %%
from ultralytics import YOLO

# %%
yolo_model = YOLO(rf"models\best.pt")

# %%
with open("models/yolo.pkl", "wb") as f:
    pickle.dump(yolo_model, f)

# %%
type(yolo_model.model)
# Out:
# ultralytics.nn.tasks.DetectionModel

# %%
y = YOLO("yolov9m.pt")

# %%
y.load(t_model)
# Out:
# Transferred 901/907 items from pretrained weights
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): RepNCSPELAN4(
#         (cv1): Conv(
#           (conv): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Sequential(
#           (0): RepCSP(
#             (cv1): Conv(
# ...
